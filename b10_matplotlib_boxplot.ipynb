# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('Household-living-costs-price-indexes-September-2020-quarter-group-facts-CSV.csv')
df.head(100)
# Out:
#                         hlpi_name  year   hlpi  tot_hhs      own  own_wm  \
# 0                  All households  2008  allhh  1560859  1087580  574406
# 1                     Beneficiary  2008  benef   185965    71256   39405
# 2         Income quintile 1 (low)  2008  disq1   312376   191470   48424
# 3               Income quintile 2  2008  disq2   312333   196203   84171
# 4               Income quintile 3  2008  disq3   312240   217657  141318
# ..                            ...   ...    ...      ...      ...     ...
# 65         Expenditure quintile 3  2020  expq3   352564   213893  119637
# 66         Expenditure quintile 4  2020  expq4   350182   235256  141104
# 67  Expenditure quintile 5 (high)  2020  expq5   351328   288779  187838
# 68                          Māori  2020  maori   329588   156459  107753
# 69                 Superannuitant  2020  super   388013   314154   38270
#
#     own_prop  own_wm_prop  prop_hhs   age  size  income  expenditure  \
# ...

# %%
df=df[['income','expenditure','eqv_income','eqv_exp']]
df.head()
# Out:
#    income  expenditure  eqv_income  eqv_exp
# 0   46704        42394       26869    25132
# 1   23404        25270       14258    15824
# 2   16747        21145       13402    14408
# 3   31308        29855       18917    18266
# 4   49106        46561       26870    24672

# %%
green_diamond = dict(markerfacecolor='g', marker='D')
plt.ylabel("($)")
plt.title('Thu Chi Household living')
plt.boxplot(df, notch= False, sym= 'r*', whis=[10,90],labels=["Income","Expenditure","Eqv Income","Eqv Expenditure"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b402edfd30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b402eef460>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b402edf9d0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1b402eefb20>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1b402eefe80>,
# ...
#  'means': []}
