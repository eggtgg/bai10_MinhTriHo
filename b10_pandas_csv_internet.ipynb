# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/eggtgg/hellominhtriho/main/cchnyt_1.csv')

# %%
df.head(10)
# Out:
#                      HoTen TenQuocTich        SoChungChi NoiCapChungChi  \
# 0       Phạm Thị Bình Minh    Việt Nam   000001/HCM-CCHN              4
# 1            Trần Thủy Cần    Việt Nam    000001/KG-CCHN              4
# 2      Trần Thị Phương Thu    Việt Nam   000002/HCM-CCHN              4
# 3      Nguyễn Thị Minh Tâm    Việt Nam  0000027/HCM-CCHN              4
# 4  Nguyễn Thái Thảo Nguyên    Việt Nam   000003/HCM-CCHN              4
# 5           ĐẶNG HOÀNG ANH        None    000004/CM-CCHN             16
# 6      Đoàn Thị Thùy Trang    Việt Nam   000004/HCM-CCHN              4
# 7      Phan Thị Hoàng Oanh    Việt Nam    000004/KT-CCHN              4
# 8        Phương Vĩnh Quang    Việt Nam    000004/ĐT-CCHN              4
# 9        Trương Thiện Niềm        None    000005/BL-CCHN              9
#
#        NgayCapChungChi                                  TenPhamViHoatDong  \
# 0  2012-03-27 00:00:00              Khám bệnh, chữa bệnh chuyên khoa Nhi.
# ...
