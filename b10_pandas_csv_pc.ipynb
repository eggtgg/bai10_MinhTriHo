# %%
import pandas as pd

# %%
df=pd.read_csv('covid_19_data_portal.csv')

# %%
df.head(10)
# Out:
#       class    category                    indicator_name series_name  \
# 0  Economic  Employment  Weekly median earnings (34 days)       Total
# 1  Economic  Employment  Weekly median earnings (34 days)       Total
# 2  Economic  Employment  Weekly median earnings (34 days)       Total
# 3  Economic  Employment  Weekly median earnings (34 days)       Total
# 4  Economic  Employment  Weekly median earnings (34 days)       Total
# 5  Economic  Employment  Weekly median earnings (34 days)       Total
# 6  Economic  Employment  Weekly median earnings (34 days)       Total
# 7  Economic  Employment  Weekly median earnings (34 days)       Total
# 8  Economic  Employment  Weekly median earnings (34 days)       Total
# 9  Economic  Employment  Weekly median earnings (34 days)       Total
#
#   sub_series_name   parameter   value units date_last_updated
# 0           Total  2019-05-05  997.14     $          26-11-20
# 1           Total  2019-05-12    1000     $          26-11-20
# ...
